# %% [markdown]
# **Task1**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.read_csv('/content/drive/MyDrive/zeotap-data/Customers.csv')
df2 = pd.read_csv('/content/drive/MyDrive/zeotap-data/Products.csv')
df3 = pd.read_csv('/content/drive/MyDrive/zeotap-data/Transactions.csv')

# %%
df1
# Out:
#     CustomerID        CustomerName         Region  SignupDate
# 0        C0001    Lawrence Carroll  South America  2022-07-10
# 1        C0002      Elizabeth Lutz           Asia  2022-02-13
# 2        C0003      Michael Rivera  South America  2024-03-07
# 3        C0004  Kathleen Rodriguez  South America  2022-10-09
# 4        C0005         Laura Weber           Asia  2022-08-15
# ..         ...                 ...            ...         ...
# 195      C0196         Laura Watts         Europe  2022-06-07
# 196      C0197    Christina Harvey         Europe  2023-03-21
# 197      C0198         Rebecca Ray         Europe  2022-02-27
# 198      C0199      Andrea Jenkins         Europe  2022-12-03
# 199      C0200         Kelly Cross           Asia  2023-06-11
#
# [200 rows x 4 columns]

# %%
df2
# Out:
#    ProductID              ProductName     Category   Price
# 0       P001     ActiveWear Biography        Books  169.30
# 1       P002    ActiveWear Smartwatch  Electronics  346.30
# 2       P003  ComfortLiving Biography        Books   44.12
# 3       P004            BookWorld Rug   Home Decor   95.69
# 4       P005          TechPro T-Shirt     Clothing  429.31
# ..       ...                      ...          ...     ...
# 95      P096     SoundWave Headphones  Electronics  307.47
# 96      P097       BookWorld Cookbook        Books  319.34
# 97      P098         SoundWave Laptop  Electronics  299.93
# 98      P099   SoundWave Mystery Book        Books  354.29
# 99      P100        HomeSense Sweater     Clothing  126.34
#
# [100 rows x 4 columns]

# %%
df3
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0          T00001      C0199      P067  2024-08-25 12:38:23         1
# 1          T00112      C0146      P067  2024-05-27 22:23:54         1
# 2          T00166      C0127      P067  2024-04-25 07:38:55         1
# 3          T00272      C0087      P067  2024-03-26 22:55:37         2
# 4          T00363      C0070      P067  2024-03-21 15:10:10         3
# ..            ...        ...       ...                  ...       ...
# 995        T00496      C0118      P037  2024-10-24 08:30:27         1
# 996        T00759      C0059      P037  2024-06-04 02:15:24         3
# 997        T00922      C0018      P037  2024-04-05 13:05:32         4
# 998        T00959      C0115      P037  2024-09-29 10:16:02         2
# 999        T00992      C0024      P037  2024-04-21 10:52:24         1
#
#      TotalValue   Price
# 0        300.68  300.68
# 1        300.68  300.68
# 2        300.68  300.68
# 3        601.36  300.68
# ...

# %%
tot_ds = pd.concat([df1,df2,df3])

# %%
tot_ds.to_csv('/content/drive/MyDrive/zeotap-data/tot_ds.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/zeotap-data/tot_ds.csv')

# %%
df
# Out:
#       Unnamed: 0 CustomerID        CustomerName         Region  SignupDate  \
# 0              0      C0001    Lawrence Carroll  South America  2022-07-10
# 1              1      C0002      Elizabeth Lutz           Asia  2022-02-13
# 2              2      C0003      Michael Rivera  South America  2024-03-07
# 3              3      C0004  Kathleen Rodriguez  South America  2022-10-09
# 4              4      C0005         Laura Weber           Asia  2022-08-15
# ...          ...        ...                 ...            ...         ...
# 1295         995      C0118                 NaN            NaN         NaN
# 1296         996      C0059                 NaN            NaN         NaN
# 1297         997      C0018                 NaN            NaN         NaN
# 1298         998      C0115                 NaN            NaN         NaN
# 1299         999      C0024                 NaN            NaN         NaN
#
#      ProductID ProductName Category   Price TransactionID  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1300 non-null   int64
#  1   CustomerID       1200 non-null   object
#  2   CustomerName     200 non-null    object
#  3   Region           200 non-null    object
#  4   SignupDate       200 non-null    object
#  5   ProductID        1100 non-null   object
#  6   ProductName      100 non-null    object
#  7   Category         100 non-null    object
#  8   Price            1100 non-null   float64
#  9   TransactionID    1000 non-null   object
#  10  TransactionDate  1000 non-null   object
#  11  Quantity         1000 non-null   float64
#  12  TotalValue       1000 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 132.2+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# CustomerID          100
# CustomerName       1100
# Region             1100
# SignupDate         1100
# ProductID           200
# ProductName        1200
# Category           1200
# Price               200
# TransactionID       300
# TransactionDate     300
# Quantity            300
# TotalValue          300
# dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0        Price     Quantity   TotalValue
# count  1300.000000  1100.000000  1000.000000  1000.000000
# mean    403.346154   272.099309     2.537000   689.995560
# std     309.353786   140.905259     1.117981   493.144478
# min       0.000000    16.080000     1.000000    16.080000
# 25%     112.000000   147.950000     2.000000   295.295000
# 50%     349.500000   299.930000     3.000000   588.880000
# 75%     674.250000   404.400000     4.000000  1011.660000
# max     999.000000   497.760000     4.000000  1991.040000

# %%
numeric_df1 = df1.select_dtypes(include=['number'])

correlation_matrix = numeric_df1.corr()

print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
# Empty DataFrame
# Columns: []
# Index: []

# %%
numeric_df2 = df2.select_dtypes(include=['number'])

correlation_matrix = numeric_df2.corr()

print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#        Price
# Price    1.0

# %%
numeric_df3 = df3.select_dtypes(include=['number'])

correlation_matrix = numeric_df3.corr()

print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#             Quantity  TotalValue     Price
# Quantity    1.000000    0.609972 -0.009378
# TotalValue  0.609972    1.000000  0.722714
# Price      -0.009378    0.722714  1.000000

# %%
df1.columns
# Out:
# Index(['CustomerID', 'CustomerName', 'Region', 'SignupDate'], dtype='object')

# %%
region_counts = df1.groupby('Region')['CustomerID'].count()

plt.figure(figsize=(8, 5))
region_counts.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Number of Customers by Region', fontsize=16)
plt.xlabel('Region', fontsize=14)
plt.ylabel('Number of Customers', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
df2.columns
# Out:
# Index(['ProductID', 'ProductName', 'Category', 'Price'], dtype='object')

# %%
region_counts = df2.groupby('Category')['Price'].count()

plt.figure(figsize=(8, 5))
region_counts.plot(kind='bar', color='pink', edgecolor='black')

plt.title('Price by Region', fontsize=16)
plt.xlabel('Region', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
df3.columns
# Out:
# Index(['TransactionID', 'CustomerID', 'ProductID', 'TransactionDate',
#        'Quantity', 'TotalValue', 'Price'],
#       dtype='object')

# %%
region_counts = df3.groupby('Quantity')['Price'].count()

plt.figure(figsize=(8, 5))
region_counts.plot(kind='bar', color='pink', edgecolor='black')

plt.title('Price by Region', fontsize=16)
plt.xlabel('Quantity', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
df1=df
df['SignupDate'] = pd.to_datetime(df['SignupDate'])

df['SignupMonth'] = df['SignupDate'].dt.month

plt.figure(figsize=(10, 6))

for region in df['Region'].unique():
    region_data = df[df['Region'] == region]['SignupMonth']
    plt.hist(region_data, bins=4, alpha=0.7, label=region)

plt.title('Customer Signups by Month (Grouped by Region)', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title='Region')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# df=df.drop('Unnamed: 0',axis=1)
sns.heatmap(df1.corr(numeric_only=True), cbar=True, cmap="YlGnBu", annot=True)
# Out:
# <Axes: >

# %%
# sns.heatmap(df2.corr(numeric_only=True), cbar=True, cmap="YlGnBu", annot=True)

# %%
sns.heatmap(df3.corr(numeric_only=True), cbar=True, cmap="YlGnBu", annot=True)
# Out:
# <Axes: >
